# %%
from tqdm.notebook import trange, tqdm
import requests

# %%
from habanero import Crossref
cr = Crossref()

# %%
import pandas as pd
data = pd.read_csv("COD-selection.csv")
# Out:
# /var/folders/gl/2h8nn4ps031g1jysgll17wz00000gn/T/ipykernel_35617/2708168232.py:2: DtypeWarning: Columns (23,24,25,32,44,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("COD-selection.csv")

# %%
data.doi.sample(n=1).iloc[0]
# Out:
# '10.1107/S1600536810027650'

# %%
 cr.works(ids = "10.1021/acs.chemrev.9b00223")['message']
# Out:
# {'indexed': {'date-parts': [[2023, 1, 10]],
#   'date-time': '2023-01-10T17:48:55Z',
#   'timestamp': 1673372935645},
#  'reference-count': 698,
#  'publisher': 'American Chemical Society (ACS)',
#  'issue': '2',
#  'license': [{'start': {'date-parts': [[2019, 6, 27]],
#     'date-time': '2019-06-27T00:00:00Z',
#     'timestamp': 1561593600000},
#    'content-version': 'stm-asf',
#    'delay-in-days': 0,
#    'URL': 'https://doi.org/10.15223/policy-029'},
#   {'start': {'date-parts': [[2019, 6, 27]],
#     'date-time': '2019-06-27T00:00:00Z',
#     'timestamp': 1561593600000},
#    'content-version': 'stm-asf',
#    'delay-in-days': 0,
#    'URL': 'https://doi.org/10.15223/policy-037'},
#   {'start': {'date-parts': [[2019, 6, 27]],
#     'date-time': '2019-06-27T00:00:00Z',
#     'timestamp': 1561593600000},
#    'content-version': 'stm-asf',
#    'delay-in-days': 0,
#    'URL': 'https://doi.org/10.15223/policy-045'}],
#  'funder': [{'DOI': '10.13039/501100006251',
#    'name': 'Universit? de Bordeaux',
#    'doi-asserted-by': 'publisher'},
#   {'DOI': '10.13039/501100004794',
#    'name': 'Centre National de la Recherche Scientifique',
#    'doi-asserted-by': 'publisher'},
#   {'DOI': '10.13039/501100004543',
#    'name': 'China Scholarship Council',
#    'doi-asserted-by': 'publisher'}],
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'short-container-title': ['Chem. Rev.'],
#  'published-print': {'date-parts': [[2020, 1, 22]]},
#  'DOI': '10.1021/acs.chemrev.9b00223',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2019, 6, 27]],
#   'date-time': '2019-06-27T18:35:38Z',
#   'timestamp': 1561660538000},
#  'page': '1438-1511',
#  'source': 'Crossref',
#  'is-referenced-by-count': 960,
#  'title': ['State of the Art and Prospects in Metal–Organic Framework (MOF)-Based and MOF-Derived Nanocatalysis'],
#  'prefix': '10.1021',
#  'volume': '120',
#  'author': [{'given': 'Qi',
#    'family': 'Wang',
#    'sequence': 'first',
#    'affiliation': [{'name': 'ISM, UMR CNRS N°5255, University of Bordeaux, 351 Cours de la Libération, 33405 Talence Cedex, France'}]},
#   {'ORCID': 'http://orcid.org/0000-0001-6446-8751',
#    'authenticated-orcid': True,
#    'given': 'Didier',
#    'family': 'Astruc',
#    'sequence': 'additional',
#    'affiliation': [{'name': 'ISM, UMR CNRS N°5255, University of Bordeaux, 351 Cours de la Libération, 33405 Talence Cedex, France'}]}],
#  'member': '316',
#  'published-online': {'date-parts': [[2019, 6, 27]]},
#  'reference': [{'key': 'ref1/cit1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1230444'},
#   {'key': 'ref2/cit2',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/nature01650'},
#   {'key': 'ref3/cit3',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.200300610'},
#   {'key': 'ref4/cit4',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5CS00940E'},
#   {'key': 'ref5/cit5',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/natrevmats.2017.75'},
#   {'key': 'ref6/cit6',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/b802258p'},
#   {'key': 'ref7/cit7',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1192160'},
#   {'key': 'ref8/cit8',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja00160a038'},
#   {'key': 'ref9/cit9',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/374792a0'},
#   {'key': 'ref10/cit10',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja00146a033'},
#   {'key': 'ref11/cit11',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ic00114a032'},
#   {'key': 'ref12/cit12',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/S1387-1811(98)00042-0'},
#   {'key': 'ref13/cit13',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5CS00307E'},
#   {'key': 'ref14/cit14',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja00082a055'},
#   {'key': 'ref15/cit15',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/b807080f'},
#   {'key': 'ref16/cit16',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00250A'},
#   {'key': 'ref17/cit17',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.200806063'},
#   {'key': 'ref18/cit18',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c1dt10354g'},
#   {'key': 'ref19/cit19',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr9003924'},
#   {'key': 'ref20/cit20',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CS00395K'},
#   {'key': 'ref21/cit21',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00724D'},
#   {'key': 'ref22/cit22',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.7b00091'},
#   {'key': 'ref23/cit23',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/b807083k'},
#   {'key': 'ref24/cit24',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2017.02.010'},
#   {'key': 'ref25/cit25',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00250A'},
#   {'key': 'ref26/cit26',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2018.02.008'},
#   {'key': 'ref27/cit27',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CS00094C'},
#   {'key': 'ref28/cit28',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2015.05.005'},
#   {'key': 'ref29/cit29',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c2cc34329k'},
#   {'key': 'ref30/cit30',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cs400959k'},
#   {'key': 'ref31/cit31',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c4sc00265b'},
#   {'key': 'ref32/cit32',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.6b01222'},
#   {'key': 'ref33/cit33',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscentsci.7b00500'},
#   {'key': 'ref34/cit34',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1098/rspa.2012.0072'},
#   {'key': 'ref35/cit35',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja800669j'},
#   {'key': 'ref36/cit36',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.micromeso.2003.12.027'},
#   {'key': 'ref37/cit37',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.200600220'},
#   {'key': 'ref38/cit38',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1083440'},
#   {'key': 'ref39/cit39',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/nature02311'},
#   {'key': 'ref40/cit40',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja045123o'},
#   {'key': 'ref41/cit41',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s10934-010-9378-0'},
#   {'key': 'ref42/cit42',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.200503778'},
#   {'key': 'ref43/cit43',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1073/pnas.0602439103'},
#   {'key': 'ref44/cit44',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ejic.200701284'},
#   {'key': 'ref45/cit45',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja8057953'},
#   {'key': 'ref46/cit46',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.283.5405.1148'},
#   {'key': 'ref47/cit47',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201001230'},
#   {'key': 'ref48/cit48',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1116275'},
#   {'key': 'ref49/cit49',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00362A'},
#   {'key': 'ref50/cit50',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4TA02984D'},
#   {'key': 'ref51/cit51',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr5002589'},
#   {'key': 'ref52/cit52',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja3055639'},
#   {'key': 'ref53/cit53',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b06859'},
#   {'key': 'ref54/cit54',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.aaf5251'},
#   {'key': 'ref55/cit55',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ac402980q'},
#   {'key': 'ref56/cit56',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.surfrep.2009.07.002'},
#   {'key': 'ref57/cit57',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201001180'},
#   {'key': 'ref58/cit58',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja403330m'},
#   {'key': 'ref59/cit59',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c4cc00785a'},
#   {'key': 'ref60/cit60',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CY01049C'},
#   {'key': 'ref61/cit61',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201300233'},
#   {'key': 'ref62/cit62',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ic5010352'},
#   {'key': 'ref63/cit63',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5DT00493D'},
#   {'key': 'ref64/cit64',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201402353'},
#   {'key': 'ref65/cit65',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja200122f'},
#   {'key': 'ref66/cit66',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201500107'},
#   {'key': 'ref67/cit67',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2014.09.065'},
#   {'key': 'ref68/cit68',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1202364'},
#   {'key': 'ref69/cit69',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CC04479G'},
#   {'key': 'ref70/cit70',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ejic.201402409'},
#   {'key': 'ref71/cit71',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201403599'},
#   {'key': 'ref72/cit72',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201206055'},
#   {'key': 'ref73/cit73',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/ncomms9248'},
#   {'key': 'ref74/cit74',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201205078'},
#   {'key': 'ref75/cit75',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ces.2014.09.050'},
#   {'key': 'ref76/cit76',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja3043905'},
#   {'key': 'ref77/cit77',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201401875'},
#   {'key': 'ref78/cit78',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja1099006'},
#   {'key': 'ref79/cit79',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja4093055'},
#   {'key': 'ref80/cit80',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5SC02925B'},
#   {'key': 'ref81/cit81',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.200800980'},
#   {'key': 'ref82/cit82',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201002088'},
#   {'key': 'ref83/cit83',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.5b00462'},
#   {'key': 'ref84/cit84',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1179713'},
#   {'key': 'ref85/cit85',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/nchem.1272'},
#   {'key': 'ref86/cit86',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c2dt12480g'},
#   {'key': 'ref87/cit87',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201200878'},
#   {'key': 'ref88/cit88',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jp4069027'},
#   {'key': 'ref89/cit89',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ejic.201500808'},
#   {'key': 'ref90/cit90',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.5b03540'},
#   {'key': 'ref91/cit91',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.6b00397'},
#   {'key': 'ref92/cit92',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.molcata.2013.04.025'},
#   {'key': 'ref93/cit93',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cs501953d'},
#   {'key': 'ref94/cit94',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cs5006635'},
#   {'key': 'ref95/cit95',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2015.07.029'},
#   {'key': 'ref96/cit96',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ejic.201001297'},
#   {'key': 'ref97/cit97',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C3CS60472A'},
#   {'key': 'ref98/cit98',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4NR06567K'},
#   {'key': 'ref99/cit99',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201510655'},
#   {'key': 'ref100/cit100',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c2cc16808a'},
#   {'key': 'ref101/cit101',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201406484'},
#   {'key': 'ref102/cit102',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja411468e'},
#   {'key': 'ref103/cit103',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CC02169G'},
#   {'key': 'ref104/cit104',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cssc.201000023'},
#   {'key': 'ref105/cit105',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.7b01495'},
#   {'key': 'ref106/cit106',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2011.02.032'},
#   {'key': 'ref107/cit107',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja01097a053'},
#   {'key': 'ref108/cit108',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2014.11.052'},
#   {'key': 'ref109/cit109',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201900051'},
#   {'key': 'ref110/cit110',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cej.2016.03.115'},
#   {'key': 'ref111/cit111',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s12274-017-1519-1'},
#   {'key': 'ref112/cit112',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.11.094'},
#   {'key': 'ref113/cit113',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA09205A'},
#   {'key': 'ref114/cit114',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2018.02.190'},
#   {'key': 'ref115/cit115',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.6b00043'},
#   {'key': 'ref116/cit116',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aic.15389'},
#   {'key': 'ref117/cit117',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.langmuir.8b03921'},
#   {'key': 'ref118/cit118',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201712372'},
#   {'key': 'ref119/cit119',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6MH00534A'},
#   {'key': 'ref120/cit120',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8CY01500G'},
#   {'key': 'ref121/cit121',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8GC03536A'},
#   {'key': 'ref122/cit122',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.8b06511'},
#   {'key': 'ref123/cit123',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b01161'},
#   {'key': 'ref124/cit124',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6TA10748F'},
#   {'key': 'ref125/cit125',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jallcom.2017.12.151'},
#   {'key': 'ref126/cit126',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jallcom.2016.10.055'},
#   {'key': 'ref127/cit127',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2017.08.167'},
#   {'key': 'ref128/cit128',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2017.11.160'},
#   {'key': 'ref129/cit129',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ica.2018.08.056'},
#   {'key': 'ref130/cit130',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c3cy00101f'},
#   {'key': 'ref131/cit131',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8SE00538A'},
#   {'key': 'ref132/cit132',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2017.06.191'},
#   {'key': 'ref133/cit133',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.inorgchem.7b01910'},
#   {'key': 'ref134/cit134',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7QI00555E'},
#   {'key': 'ref135/cit135',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201800625'},
#   {'key': 'ref136/cit136',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.7b00182'},
#   {'key': 'ref137/cit137',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.accounts.7b00132'},
#   {'key': 'ref138/cit138',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5CS00618J'},
#   {'key': 'ref139/cit139',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.06.084'},
#   {'key': 'ref140/cit140',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201701416'},
#   {'key': 'ref141/cit141',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cej.2018.12.158'},
#   {'key': 'ref142/cit142',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8RA10198A'},
#   {'key': 'ref143/cit143',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ente.201800319'},
#   {'key': 'ref144/cit144',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/S1872-2067(17)62852-3'},
#   {'key': 'ref145/cit145',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2018.02.009'},
#   {'key': 'ref146/cit146',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.accounts.5b00134'},
#   {'key': 'ref147/cit147',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C2CS35333D'},
#   {'key': 'ref148/cit148',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2017.10.047'},
#   {'key': 'ref149/cit149',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201801878'},
#   {'key': 'ref150/cit150',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201801311'},
#   {'key': 'ref151/cit151',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jiec.2016.10.037'},
#   {'key': 'ref152/cit152',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2017.07.068'},
#   {'key': 'ref153/cit153',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8DT03416H'},
#   {'key': 'ref154/cit154',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b11241'},
#   {'key': 'ref155/cit155',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201704341'},
#   {'key': 'ref156/cit156',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201700683'},
#   {'key': 'ref157/cit157',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.200900129'},
#   {'key': 'ref158/cit158',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.2174/157017912802651456'},
#   {'key': 'ref159/cit159',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CY00111G'},
#   {'key': 'ref160/cit160',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.5b01846'},
#   {'key': 'ref161/cit161',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.01.052'},
#   {'key': 'ref162/cit162',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00629A'},
#   {'key': 'ref163/cit163',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.8b00547'},
#   {'key': 'ref164/cit164',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1128383'},
#   {'key': 'ref165/cit165',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/b509595f'},
#   {'key': 'ref166/cit166',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aoc.4132'},
#   {'key': 'ref167/cit167',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201700095'},
#   {'key': 'ref168/cit168',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2017.10.030'},
#   {'key': 'ref169/cit169',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201705400'},
#   {'key': 'ref170/cit170',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cssc.201801641'},
#   {'key': 'ref171/cit171',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.03.059'},
#   {'key': 'ref172/cit172',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cattod.2017.09.002'},
#   {'key': 'ref173/cit173',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5CC01131K'},
#   {'key': 'ref174/cit174',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jp101125j'},
#   {'key': 'ref175/cit175',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c2cs35029g'},
#   {'key': 'ref176/cit176',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2015.01.002'},
#   {'key': 'ref177/cit177',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CC05946H'},
#   {'key': 'ref178/cit178',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ange.201801588'},
#   {'key': 'ref179/cit179',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ejic.201701320'},
#   {'key': 'ref180/cit180',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.03.221'},
#   {'key': 'ref181/cit181',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8NR04262D'},
#   {'key': 'ref182/cit182',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cej.2017.09.154'},
#   {'key': 'ref183/cit183',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201701693'},
#   {'key': 'ref184/cit184',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201602996'},
#   {'key': 'ref185/cit185',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.inorgchem.6b02476'},
#   {'key': 'ref186/cit186',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b01970'},
#   {'key': 'ref187/cit187',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8CC06099A'},
#   {'key': 'ref188/cit188',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201802021'},
#   {'key': 'ref189/cit189',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201704576'},
#   {'key': 'ref190/cit190',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1080/01614949808007106'},
#   {'key': 'ref191/cit191',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1240148'},
#   {'key': 'ref192/cit192',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2016.05.013'},
#   {'key': 'ref193/cit193',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/nature19763'},
#   {'key': 'ref194/cit194',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201801289'},
#   {'key': 'ref195/cit195',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201702103'},
#   {'key': 'ref196/cit196',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201704318'},
#   {'key': 'ref197/cit197',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201600878'},
#   {'key': 'ref198/cit198',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201704119'},
#   {'key': 'ref199/cit199',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5GC02530C'},
#   {'key': 'ref200/cit200',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5GC02615F'},
#   {'key': 'ref201/cit201',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201600956'},
#   {'key': 'ref202/cit202',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cej.2017.07.099'},
#   {'key': 'ref203/cit203',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.6b00816'},
#   {'key': 'ref204/cit204',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr300463y'},
#   {'key': 'ref205/cit205',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201507458'},
#   {'key': 'ref206/cit206',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2017.01.007'},
#   {'key': 'ref207/cit207',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6MH00484A'},
#   {'key': 'ref208/cit208',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cssc.201800016'},
#   {'key': 'ref209/cit209',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7QM00328E'},
#   {'key': 'ref210/cit210',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201702812'},
#   {'key': 'ref211/cit211',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8CY00468D'},
#   {'key': 'ref212/cit212',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2017.02.031'},
#   {'key': 'ref213/cit213',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.04.024'},
#   {'key': 'ref214/cit214',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3866/PKU.WHXB201803212'},
#   {'key': 'ref215/cit215',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b00058'},
#   {'key': 'ref216/cit216',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcou.2018.03.015'},
#   {'key': 'ref217/cit217',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.8b01691'},
#   {'key': 'ref218/cit218',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/s41467-017-01910-9'},
#   {'key': 'ref219/cit219',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2017.04.285'},
#   {'key': 'ref220/cit220',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.6b02464'},
#   {'key': 'ref221/cit221',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b00562'},
#   {'key': 'ref222/cit222',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.aan6245'},
#   {'key': 'ref223/cit223',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7EN00909G'},
#   {'key': 'ref224/cit224',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7SC04269H'},
#   {'key': 'ref225/cit225',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jiec.2017.04.006'},
#   {'key': 'ref226/cit226',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6TA03688K'},
#   {'key': 'ref227/cit227',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcata.2018.02.007'},
#   {'key': 'ref228/cit228',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr068217k'},
#   {'key': 'ref229/cit229',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.05.039'},
#   {'key': 'ref230/cit230',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/nchem.1272'},
#   {'key': 'ref231/cit231',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00426A'},
#   {'key': 'ref232/cit232',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201604802'},
#   {'key': 'ref233/cit233',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b01686'},
#   {'key': 'ref234/cit234',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/s41565-018-0197-9'},
#   {'key': 'ref235/cit235',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/s41929-018-0146-x'},
#   {'key': 'ref236/cit236',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2012.09.012'},
#   {'key': 'ref237/cit237',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.7b00167'},
#   {'key': 'ref238/cit238',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c3cs60282f'},
#   {'key': 'ref239/cit239',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2018.12.004'},
#   {'key': 'ref240/cit240',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ar3000508'},
#   {'key': 'ref241/cit241',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c1cy00068c'},
#   {'key': 'ref242/cit242',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8NR01336E'},
#   {'key': 'ref243/cit243',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CY01385J'},
#   {'key': 'ref244/cit244',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.6b03632'},
#   {'key': 'ref245/cit245',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.6b02614'},
#   {'key': 'ref246/cit246',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.oprd.5b00204'},
#   {'key': 'ref247/cit247',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.6b00556'},
#   {'key': 'ref248/cit248',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/b707314n'},
#   {'key': 'ref249/cit249',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CY00912G'},
#   {'key': 'ref250/cit250',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.jpcc.8b05882'},
#   {'key': 'ref251/cit251',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.inorgchem.8b02206'},
#   {'key': 'ref252/cit252',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.jpcc.7b02425'},
#   {'key': 'ref253/cit253',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/polym10101089'},
#   {'key': 'ref254/cit254',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b12380'},
#   {'key': 'ref255/cit255',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CC04926A'},
#   {'key': 'ref256/cit256',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.7b03270'},
#   {'key': 'ref257/cit257',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b05018'},
#   {'key': 'ref258/cit258',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA10334D'},
#   {'key': 'ref259/cit259',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cattod.2016.03.044'},
#   {'key': 'ref260/cit260',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201000378'},
#   {'key': 'ref261/cit261',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1246/cl.1987.405'},
#   {'key': 'ref262/cit262',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/tcr.201600046'},
#   {'key': 'ref263/cit263',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.200353570'},
#   {'key': 'ref264/cit264',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA03006A'},
#   {'key': 'ref265/cit265',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b03555'},
#   {'key': 'ref266/cit266',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8NR05801F'},
#   {'key': 'ref267/cit267',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201800343'},
#   {'key': 'ref268/cit268',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.catcom.2012.04.028'},
#   {'key': 'ref269/cit269',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2017.02.088'},
#   {'key': 'ref270/cit270',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.fuel.2018.04.071'},
#   {'key': 'ref271/cit271',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C4CY01147C'},
#   {'key': 'ref272/cit272',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2017.03.179'},
#   {'key': 'ref273/cit273',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201800773'},
#   {'key': 'ref274/cit274',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.inorgchem.8b01232'},
#   {'key': 'ref275/cit275',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b10336'},
#   {'key': 'ref276/cit276',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.8b01366'},
#   {'key': 'ref277/cit277',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja106935d'},
#   {'key': 'ref278/cit278',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemmater.7b00544'},
#   {'key': 'ref279/cit279',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cej.2017.10.091'},
#   {'key': 'ref280/cit280',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.7b00443'},
#   {'key': 'ref281/cit281',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/asia.201800583'},
#   {'key': 'ref282/cit282',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.8b04506'},
#   {'key': 'ref283/cit283',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1246/bcsj.44.581'},
#   {'key': 'ref284/cit284',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jo00979a024'},
#   {'key': 'ref285/cit285',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr9903048'},
#   {'key': 'ref286/cit286',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.200500766'},
#   {'key': 'ref287/cit287',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adsc.200505473'},
#   {'key': 'ref288/cit288',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/B506276B'},
#   {'key': 'ref289/cit289',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/slct.201701270'},
#   {'key': 'ref290/cit290',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b03525'},
#   {'key': 'ref291/cit291',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.inorgchem.7b03271'},
#   {'key': 'ref292/cit292',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.8b03505'},
#   {'key': 'ref293/cit293',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/c1cs15079k'},
#   {'key': 'ref294/cit294',
#    'unstructured': 'Suzuki, A. In  Modern Arene Chemistry; Astruc, D., Ed. Wiley-VCH: Weinheim, 2003; pp 53–106.'},
#   {'key': 'ref295/cit295',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2019.01.008'},
#   {'key': 'ref296/cit296',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.200703067'},
#   {'key': 'ref297/cit297',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ar400168s'},
#   {'key': 'ref298/cit298',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b16136'},
#   {'key': 'ref299/cit299',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2018.02.026'},
#   {'key': 'ref300/cit300',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s10562-017-2289-9'},
#   {'key': 'ref301/cit301',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/tcr.201700100'},
#   {'key': 'ref302/cit302',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8CY00662H'},
#   {'key': 'ref303/cit303',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2017.02.013'},
#   {'key': 'ref304/cit304',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s12274-016-1341-1'},
#   {'key': 'ref305/cit305',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smtd.201800216'},
#   {'key': 'ref306/cit306',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s40242-017-6420-7'},
#   {'key': 'ref307/cit307',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/ma10020099'},
#   {'key': 'ref308/cit308',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ejoc.200400511'},
#   {'key': 'ref309/cit309',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s10562-017-2153-y'},
#   {'key': 'ref310/cit310',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.inorgchem.7b03084'},
#   {'key': 'ref311/cit311',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA06766J'},
#   {'key': 'ref312/cit312',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.6b10999'},
#   {'key': 'ref313/cit313',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsomega.8b00157'},
#   {'key': 'ref314/cit314',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b12166'},
#   {'key': 'ref315/cit315',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201605852'},
#   {'key': 'ref316/cit316',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201106310'},
#   {'key': 'ref317/cit317',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aoc.3957'},
#   {'key': 'ref318/cit318',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7GC00276A'},
#   {'key': 'ref319/cit319',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201811506'},
#   {'key': 'ref320/cit320',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3389/fenrg.2014.00063'},
#   {'key': 'ref321/cit321',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cssc.201700245'},
#   {'key': 'ref322/cit322',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201800411'},
#   {'key': 'ref323/cit323',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA04667K'},
#   {'key': 'ref324/cit324',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1218930'},
#   {'key': 'ref325/cit325',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201509133'},
#   {'key': 'ref326/cit326',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adsc.201800343'},
#   {'key': 'ref327/cit327',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.fuel.2018.02.014'},
#   {'key': 'ref328/cit328',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7GC02087B'},
#   {'key': 'ref329/cit329',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/b802430h'},
#   {'key': 'ref330/cit330',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.200801130'},
#   {'key': 'ref331/cit331',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201600423'},
#   {'key': 'ref332/cit332',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2017.09.001'},
#   {'key': 'ref333/cit333',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201700518'},
#   {'key': 'ref334/cit334',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.7b00587'},
#   {'key': 'ref335/cit335',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.6b02573'},
#   {'key': 'ref336/cit336',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1200832'},
#   {'key': 'ref337/cit337',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201700874'},
#   {'key': 'ref338/cit338',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/nchem.1095'},
#   {'key': 'ref339/cit339',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201801193'},
#   {'key': 'ref340/cit340',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.5b10727'},
#   {'key': 'ref341/cit341',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemmater.5b02877'},
#   {'key': 'ref342/cit342',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.5b02465'},
#   {'key': 'ref343/cit343',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201407031'},
#   {'key': 'ref344/cit344',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.5b02688'},
#   {'key': 'ref345/cit345',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja201165c'},
#   {'key': 'ref346/cit346',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5NR01955A'},
#   {'key': 'ref347/cit347',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5EE02460A'},
#   {'key': 'ref348/cit348',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5TA09743F'},
#   {'key': 'ref349/cit349',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201505691'},
#   {'key': 'ref350/cit350',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.1215868'},
#   {'key': 'ref351/cit351',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.7b00120'},
#   {'key': 'ref352/cit352',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CC06660K'},
#   {'key': 'ref353/cit353',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b01541'},
#   {'key': 'ref354/cit354',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201807419'},
#   {'key': 'ref355/cit355',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b00165'},
#   {'key': 'ref356/cit356',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201800396'},
#   {'key': 'ref357/cit357',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.8b01575'},
#   {'key': 'ref358/cit358',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b02244'},
#   {'key': 'ref359/cit359',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.8b02921'},
#   {'key': 'ref360/cit360',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2017.03.028'},
#   {'key': 'ref361/cit361',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.04.026'},
#   {'key': 'ref362/cit362',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201707238'},
#   {'key': 'ref363/cit363',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b00598'},
#   {'key': 'ref364/cit364',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2017.06.179'},
#   {'key': 'ref365/cit365',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2017.12.045'},
#   {'key': 'ref366/cit366',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201802011'},
#   {'key': 'ref367/cit367',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8NR01811A'},
#   {'key': 'ref368/cit368',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201602873'},
#   {'key': 'ref369/cit369',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2018.12.184'},
#   {'key': 'ref370/cit370',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/celc.201801238'},
#   {'key': 'ref371/cit371',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b01037'},
#   {'key': 'ref372/cit372',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.11.035'},
#   {'key': 'ref373/cit373',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.8b06195'},
#   {'key': 'ref374/cit374',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.5b00482'},
#   {'key': 'ref375/cit375',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2017.11.003'},
#   {'key': 'ref376/cit376',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201703711'},
#   {'key': 'ref377/cit377',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CC09223G'},
#   {'key': 'ref378/cit378',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7NR08474A'},
#   {'key': 'ref379/cit379',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2017.07.032'},
#   {'key': 'ref380/cit380',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.08.033'},
#   {'key': 'ref381/cit381',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2018.11.051'},
#   {'key': 'ref382/cit382',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.8b01566'},
#   {'key': 'ref383/cit383',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b04553'},
#   {'key': 'ref384/cit384',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b06384'},
#   {'key': 'ref385/cit385',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6TA10405C'},
#   {'key': 'ref386/cit386',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2018.04.090'},
#   {'key': 'ref387/cit387',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2018.08.129'},
#   {'key': 'ref388/cit388',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA01325J'},
#   {'key': 'ref389/cit389',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.6b12065'},
#   {'key': 'ref390/cit390',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/ncomms14969'},
#   {'key': 'ref391/cit391',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201705324'},
#   {'key': 'ref392/cit392',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA09939H'},
#   {'key': 'ref393/cit393',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6TA09994G'},
#   {'key': 'ref394/cit394',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201000397'},
#   {'key': 'ref395/cit395',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2017.05.022'},
#   {'key': 'ref396/cit396',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CS00328A'},
#   {'key': 'ref397/cit397',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5DT04025F'},
#   {'key': 'ref398/cit398',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201300510'},
#   {'key': 'ref399/cit399',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201701143'},
#   {'key': 'ref400/cit400',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.aad0832'},
#   {'key': 'ref401/cit401',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.elecom.2017.12.011'},
#   {'key': 'ref402/cit402',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2017.02.063'},
#   {'key': 'ref403/cit403',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s12274-017-1765-2'},
#   {'key': 'ref404/cit404',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA04662F'},
#   {'key': 'ref405/cit405',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201702048'},
#   {'key': 'ref406/cit406',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA11400E'},
#   {'key': 'ref407/cit407',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.09.063'},
#   {'key': 'ref408/cit408',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201801678'},
#   {'key': 'ref409/cit409',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201809144'},
#   {'key': 'ref410/cit410',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201704035'},
#   {'key': 'ref411/cit411',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b11101'},
#   {'key': 'ref412/cit412',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2017.08.209'},
#   {'key': 'ref413/cit413',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.03.036'},
#   {'key': 'ref414/cit414',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b03034'},
#   {'key': 'ref415/cit415',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201703796'},
#   {'key': 'ref416/cit416',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201704211'},
#   {'key': 'ref417/cit417',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2019.01.100'},
#   {'key': 'ref418/cit418',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/slct.201802614'},
#   {'key': 'ref419/cit419',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.6b16534'},
#   {'key': 'ref420/cit420',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2017.05.043'},
#   {'key': 'ref421/cit421',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/celc.201700883'},
#   {'key': 'ref422/cit422',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA10952D'},
#   {'key': 'ref423/cit423',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b13359'},
#   {'key': 'ref424/cit424',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201801554'},
#   {'key': 'ref425/cit425',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CY00035A'},
#   {'key': 'ref426/cit426',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b07142'},
#   {'key': 'ref427/cit427',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2017.08.040'},
#   {'key': 'ref428/cit428',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA06272A'},
#   {'key': 'ref429/cit429',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jallcom.2018.08.096'},
#   {'key': 'ref430/cit430',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2017.10.080'},
#   {'key': 'ref431/cit431',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201702753'},
#   {'key': 'ref432/cit432',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jpowsour.2014.07.179'},
#   {'key': 'ref433/cit433',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b02926'},
#   {'key': 'ref434/cit434',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201702734'},
#   {'key': 'ref435/cit435',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cs500923c'},
#   {'key': 'ref436/cit436',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201704021'},
#   {'key': 'ref437/cit437',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.7b02718'},
#   {'key': 'ref438/cit438',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA05985C'},
#   {'key': 'ref439/cit439',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201702300'},
#   {'key': 'ref440/cit440',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/aenm.201701592'},
#   {'key': 'ref441/cit441',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5SC04425A'},
#   {'key': 'ref442/cit442',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.7b12420'},
#   {'key': 'ref443/cit443',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/celc.201600452'},
#   {'key': 'ref444/cit444',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b10680'},
#   {'key': 'ref445/cit445',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b10338'},
#   {'key': 'ref446/cit446',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7MH00706J'},
#   {'key': 'ref447/cit447',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA01310A'},
#   {'key': 'ref448/cit448',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA01453H'},
#   {'key': 'ref449/cit449',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b20184'},
#   {'key': 'ref450/cit450',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b00153'},
#   {'key': 'ref451/cit451',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201605957'},
#   {'key': 'ref452/cit452',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA10218F'},
#   {'key': 'ref453/cit453',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2018.12.020'},
#   {'key': 'ref454/cit454',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2018.12.031'},
#   {'key': 'ref455/cit455',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2018.12.060'},
#   {'key': 'ref456/cit456',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jpowsour.2018.04.027'},
#   {'key': 'ref457/cit457',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.electacta.2017.08.047'},
#   {'key': 'ref458/cit458',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201703455'},
#   {'key': 'ref459/cit459',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b06166'},
#   {'key': 'ref460/cit460',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201704233'},
#   {'key': 'ref461/cit461',
# ...
#    'DOI': '10.1021/ja8034637'},
#   {'key': 'ref552/cit552',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscentsci.7b00497'},
#   {'key': 'ref553/cit553',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201712925'},
#   {'key': 'ref554/cit554',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2018.11.016'},
#   {'key': 'ref555/cit555',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.09.036'},
#   {'key': 'ref556/cit556',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ijhydene.2018.12.045'},
#   {'key': 'ref557/cit557',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8NR06471G'},
#   {'key': 'ref558/cit558',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b11920'},
#   {'key': 'ref559/cit559',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA10284D'},
#   {'key': 'ref560/cit560',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b04461'},
#   {'key': 'ref561/cit561',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.01.048'},
#   {'key': 'ref562/cit562',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acssuschemeng.7b03169'},
#   {'key': 'ref563/cit563',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.10.051'},
#   {'key': 'ref564/cit564',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.06.001'},
#   {'key': 'ref565/cit565',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA10225A'},
#   {'key': 'ref566/cit566',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8DT02681E'},
#   {'key': 'ref567/cit567',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2016.07.033'},
#   {'key': 'ref568/cit568',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.08.081'},
#   {'key': 'ref569/cit569',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b13912'},
#   {'key': 'ref570/cit570',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8CY00604K'},
#   {'key': 'ref571/cit571',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CY02328B'},
#   {'key': 'ref572/cit572',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/advs.201700590'},
#   {'key': 'ref573/cit573',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA07362G'},
#   {'key': 'ref574/cit574',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ja302846n'},
#   {'key': 'ref575/cit575',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.03.057'},
#   {'key': 'ref576/cit576',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6CY02145J'},
#   {'key': 'ref577/cit577',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.8b03233'},
#   {'key': 'ref578/cit578',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.11.018'},
#   {'key': 'ref579/cit579',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201603369'},
#   {'key': 'ref580/cit580',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.mssp.2018.02.013'},
#   {'key': 'ref581/cit581',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA04916E'},
#   {'key': 'ref582/cit582',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.nanoen.2017.01.046'},
#   {'key': 'ref583/cit583',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.01.040'},
#   {'key': 'ref584/cit584',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cssc.201702316'},
#   {'key': 'ref585/cit585',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201800320'},
#   {'key': 'ref586/cit586',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201705112'},
#   {'key': 'ref587/cit587',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201711725'},
#   {'key': 'ref588/cit588',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adma.201707377'},
#   {'key': 'ref589/cit589',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA00148G'},
#   {'key': 'ref590/cit590',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201806077'},
#   {'key': 'ref591/cit591',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jssc.2019.01.006'},
#   {'key': 'ref592/cit592',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201805663'},
#   {'key': 'ref593/cit593',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201605473'},
#   {'key': 'ref594/cit594',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsenergylett.6b00540'},
#   {'key': 'ref595/cit595',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.07.020'},
#   {'key': 'ref596/cit596',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.07.046'},
#   {'key': 'ref597/cit597',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.12.024'},
#   {'key': 'ref598/cit598',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201707110'},
#   {'key': 'ref599/cit599',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/smll.201603879'},
#   {'key': 'ref600/cit600',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsenergylett.6b00558'},
#   {'key': 'ref601/cit601',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA09865D'},
#   {'key': 'ref602/cit602',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/277637a0'},
#   {'key': 'ref603/cit603',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cattod.2017.10.006'},
#   {'key': 'ref604/cit604',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6EE00383D'},
#   {'key': 'ref605/cit605',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.200601003'},
#   {'key': 'ref606/cit606',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CY01653K'},
#   {'key': 'ref607/cit607',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcou.2018.01.024'},
#   {'key': 'ref608/cit608',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.7b11150'},
#   {'key': 'ref609/cit609',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1063/1.5021098'},
#   {'key': 'ref610/cit610',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA00437K'},
#   {'key': 'ref611/cit611',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.6b16817'},
#   {'key': 'ref612/cit612',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA09192C'},
#   {'key': 'ref613/cit613',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.12.045'},
#   {'key': 'ref614/cit614',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.8b04887'},
#   {'key': 'ref615/cit615',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201811545'},
#   {'key': 'ref616/cit616',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201804925'},
#   {'key': 'ref617/cit617',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CY02286G'},
#   {'key': 'ref618/cit618',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2016.07.032'},
#   {'key': 'ref619/cit619',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b14282'},
#   {'key': 'ref620/cit620',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8SC02809E'},
#   {'key': 'ref621/cit621',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA05970E'},
#   {'key': 'ref622/cit622',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcou.2016.10.006'},
#   {'key': 'ref623/cit623',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8TA07158F'},
#   {'key': 'ref624/cit624',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsnano.8b00110'},
#   {'key': 'ref625/cit625',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1088/1361-6528/aabdb1'},
#   {'key': 'ref626/cit626',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.6b11027'},
#   {'key': 'ref627/cit627',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s12274-018-2269-4'},
#   {'key': 'ref628/cit628',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/s41598-017-00574-1'},
#   {'key': 'ref629/cit629',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/admi.201801062'},
#   {'key': 'ref630/cit630',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2018.12.005'},
#   {'key': 'ref631/cit631',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsenergylett.8b01658'},
#   {'key': 'ref632/cit632',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cej.2018.10.120'},
#   {'key': 'ref633/cit633',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/cctc.201600808'},
#   {'key': 'ref634/cit634',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.molstruc.2019.01.038'},
#   {'key': 'ref635/cit635',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2017.12.013'},
#   {'key': 'ref636/cit636',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA03840B'},
#   {'key': 'ref637/cit637',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.10.165'},
#   {'key': 'ref638/cit638',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.07.037'},
#   {'key': 'ref639/cit639',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CY01979C'},
#   {'key': 'ref640/cit640',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.10.029'},
#   {'key': 'ref641/cit641',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s11164-018-3682-8'},
#   {'key': 'ref642/cit642',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.cplett.2019.02.005'},
#   {'key': 'ref643/cit643',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2017.03.140'},
#   {'key': 'ref644/cit644',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.6b15792'},
#   {'key': 'ref645/cit645',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.colsurfa.2019.02.007'},
#   {'key': 'ref646/cit646',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2017.01.060'},
#   {'key': 'ref647/cit647',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/adfm.201705588'},
#   {'key': 'ref648/cit648',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s11164-018-3681-9'},
#   {'key': 'ref649/cit649',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.10.048'},
#   {'key': 'ref650/cit650',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA02184D'},
#   {'key': 'ref651/cit651',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apsusc.2018.09.144'},
#   {'key': 'ref652/cit652',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apt.2018.09.011'},
#   {'key': 'ref653/cit653',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.chemosphere.2018.12.086'},
#   {'key': 'ref654/cit654',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.03.075'},
#   {'key': 'ref655/cit655',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jallcom.2016.08.176'},
#   {'key': 'ref656/cit656',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1177/0748233718797247'},
#   {'key': 'ref657/cit657',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1007/s00339-018-2324-8'},
#   {'key': 'ref658/cit658',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jclepro.2018.10.141'},
#   {'key': 'ref659/cit659',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2018.12.024'},
#   {'key': 'ref660/cit660',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acsami.8b00198'},
#   {'key': 'ref661/cit661',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcis.2016.11.007'},
#   {'key': 'ref662/cit662',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CE00398F'},
#   {'key': 'ref663/cit663',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA09166D'},
#   {'key': 'ref664/cit664',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemmater.7b01243'},
#   {'key': 'ref665/cit665',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7TA01909B'},
#   {'key': 'ref666/cit666',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acscatal.7b04219'},
#   {'key': 'ref667/cit667',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2018.05.033'},
#   {'key': 'ref668/cit668',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.jcat.2018.02.033'},
#   {'key': 'ref669/cit669',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/chem.201605576'},
#   {'key': 'ref670/cit670',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.apcatb.2017.10.027'},
#   {'key': 'ref671/cit671',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr900327d'},
#   {'key': 'ref672/cit672',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/ange.201504473'},
#   {'key': 'ref673/cit673',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201809530'},
#   {'key': 'ref674/cit674',
#    'doi-asserted-by': 'crossref',
#    'volume-title': 'Modern Surface Organometallic Chemistry',
#    'author': 'Basset J.-M.',
#    'year': '2009',
#    'DOI': '10.1002/9783527627097'},
#   {'key': 'ref675/cit675',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8CS00356D'},
#   {'key': 'ref676/cit676',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CS00033B'},
#   {'key': 'ref677/cit677',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1038/ncomms6979'},
#   {'key': 'ref678/cit678',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.chempr.2016.05.001'},
#   {'key': 'ref679/cit679',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/anie.201704120'},
#   {'key': 'ref680/cit680',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C7CS00058H'},
#   {'key': 'ref681/cit681',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C6MH00312E'},
#   {'key': 'ref682/cit682',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.8b11525'},
#   {'key': 'ref683/cit683',
#    'volume-title': 'Electron Transfer and Radical Processes in Transition Metal Chemistry',
#    'author': 'Astruc D.',
#    'year': '1995'},
#   {'key': 'ref684/cit684',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C8SC04138E'},
#   {'key': 'ref685/cit685',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1080/02603599908020417'},
#   {'key': 'ref686/cit686',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/ar970171h'},
#   {'key': 'ref687/cit687',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/acs.chemrev.7b00542'},
#   {'key': 'ref688/cit688',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2018.08.012'},
#   {'key': 'ref689/cit689',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/cr030698+'},
#   {'key': 'ref690/cit690',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.3390/catal9010052'},
#   {'key': 'ref691/cit691',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2018.10.003'},
#   {'key': 'ref692/cit692',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5TA05440K'},
#   {'key': 'ref693/cit693',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1021/jacs.6b01233'},
#   {'key': 'ref694/cit694',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ccr.2018.04.012'},
#   {'key': 'ref695/cit695',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.ensm.2017.12.027'},
#   {'key': 'ref696/cit696',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1126/science.aal1585'},
#   {'key': 'ref697/cit697',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1039/C5DT03522H'},
#   {'key': 'ref698/cit698',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.chemosphere.2018.06.114'}],
#  'container-title': ['Chemical Reviews'],
#  'original-title': [],
#  'language': 'en',
#  'link': [{'URL': 'https://pubs.acs.org/doi/pdf/10.1021/acs.chemrev.9b00223',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'deposited': {'date-parts': [[2022, 3, 21]],
#   'date-time': '2022-03-21T22:40:33Z',
#   'timestamp': 1647902433000},
#  'score': 1,
#  'resource': {'primary': {'URL': 'https://pubs.acs.org/doi/10.1021/acs.chemrev.9b00223'}},
#  'subtitle': [],
#  'short-title': [],
#  'issued': {'date-parts': [[2019, 6, 27]]},
#  'references-count': 698,
#  'journal-issue': {'issue': '2',
#   'published-print': {'date-parts': [[2020, 1, 22]]}},
#  'alternative-id': ['10.1021/acs.chemrev.9b00223'],
#  'URL': 'http://dx.doi.org/10.1021/acs.chemrev.9b00223',
#  'relation': {},
#  'ISSN': ['0009-2665', '1520-6890'],
#  'issn-type': [{'value': '0009-2665', 'type': 'print'},
#   {'value': '1520-6890', 'type': 'electronic'}],
#  'subject': ['General Chemistry'],
#  'published': {'date-parts': [[2019, 6, 27]]}}

# %%
x = 0
for doi in tqdm(data.doi.sample(n=10).items()):
    try:
        cr.works(ids = doi)['message']['abstract']
        x+=1
        print(x)
    except:
        pass
# Out:
# 0it [00:00, ?it/s]

# %%
from scidownl import scihub_download
import os

paper = "https://doi.org/"+data.doi.sample(n=1).iloc[0]
paper_type = "doi"
out = "./tmp.pdf"
scihub_download(paper, paper_type=paper_type, out=out)
pdfFileObj = open('tmp.pdf', 'rb')

pdfReader = PyPDF2.PdfReader(pdfFileObj)
   
text = pdfReader.pages[0].extract_text()

pdfFileObj.close()
os.remove("tmp.pdf")
# Out:
# [INFO] | 2023/01/10 19:29:39 | Choose scihub url [0]: http://sci-hub.se
# [WARNING] | 2023/01/10 19:30:28 | Error occurs, task status: crawling_failed, error: HTTPConnectionPool(host='sci-hub.se', port=80): Read timed out. (read timeout=None)
# [INFO] | 2023/01/10 19:30:28 | Choose scihub url [1]: https://sci-hub.st
# [WARNING] | 2023/01/10 19:31:18 | Error occurs, task status: crawling_failed, error: ('Connection aborted.', TimeoutError(60, 'Operation timed out'))
# [INFO] | 2023/01/10 19:31:18 | Choose scihub url [2]: http://sci-hub.st
# [WARNING] | 2023/01/10 19:32:08 | Error occurs, task status: crawling_failed, error: HTTPConnectionPool(host='sci-hub.st', port=80): Read timed out. (read timeout=None)
# [INFO] | 2023/01/10 19:32:08 | Choose scihub url [3]: https://sci-hub.se
# [INFO] | 2023/01/10 19:32:09 | <- Request: scihub_url=https://sci-hub.se, source=DoiSource[type=doi, id=doi.org/10.1107/S1600536811037263]
# [INFO] | 2023/01/10 19:32:09 | -> Response: status_code=200, content_length=7005
# [INFO] | 2023/01/10 19:32:09 | * Extracted information: {'url': 'https://zero.sci-hub.se/3971/be4c8f734fdf062aa222d14e8f3a23df/li2011.pdf', 'title': 'A new langbeinite-type phosphate  K2AlSn(PO4)3. Acta Crystallographica Section E Structure Reports Online, 67(10), i56–i56'}
#  93% [....................................................................      ]  958464 / 1029592
# [INFO] | 2023/01/10 19:32:10 | ↓ Successfully download the url to: ./tmp.pdf
# 100% [..........................................................................] 1029592 / 1029592

# %%
text
# Out:
# 'A new langbeinite-type phosphate:\nK2AlSn(PO 4)3\nHai-Yan Li* and Dan Zhao\nDepartment of Physics and Chemistry, Henan Polytechnic University, Jiaozuo,\nHenan 454000, People’s Republic of China\nCorrespondence e-mail: henanligong1996@163.com\nReceived 30 July 2011; accepted 13 September 2011Key indicators: single-crystal X-ray study; T= 296 K; mean /C27(P–O) = 0.005 A ˚;\ndisorder in main residue; Rfactor = 0.029; wRfactor = 0.074; data-to-parameter\nratio = 13.7.\nSingle crystals of the title compound, dipotassium aluminium\ntin(IV) tris[phosphate(V)], K 2AlSn(PO 4)3, were synthesized\nby a high temperature reaction in a platinum crucible. In thestructure, the Al\nIIIand SnIVatoms occupy the same site on a\nthreefold rotation axis with occupational disorder in a 1:1ratio. In the three-dimensional structure, Al/SnO\n6octahedra\nand PO 4tetrahedra are interconnected viatheir vertices,\nyielding a [Al/SnP 3O12]nframework. The K atoms (site\nsymmetry 3) reside in the large cavities delimited by the [Al/\nSnP 3O12]nframework, and are surrounded by 12 O atoms.\nRelated literature\nFor the mineral langbeinite, K 2Mg 2(SO 4)3, see: Zemann &\nZemann (1957). For related langbeinite-type compounds, see:\nAatiq et al. (2006); Norberg (2002); Ogorodnyk et al. (2006);\nOrlova et al. (2003); Zatovsky et al. (2007); Zhao et al. (2009).\nExperimental\nCrystal data\nK2AlSn(PO 4)3\nMr= 508.78\nCubic, P213a= 9.7980 (8) A ˚\nV= 940.62 (13) A ˚3\nZ=4MoK/C11radiation\n/C22= 4.28 mm/C01T= 296 K\n0.15/C20.05/C20.05 mm\nData collection\nBruker APEXII CCD area-detector\ndiffractometer\nAbsorption correction: multi-scan\n(SADABS ; Sheldrick, 1996)\nTmin= 0.566, Tmax= 0.8156146 measured reﬂections\n811 independent reﬂections\n782 reﬂections with I>2/C27(I)\nRint= 0.065\nReﬁnement\nR[F2>2/C27(F2)] = 0.029\nwR(F2) = 0.074\nS= 1.18\n811 reﬂections59 parameters/C1/C26\nmax= 0.53 e A ˚/C03\n/C1/C26min=/C00.60 e A ˚/C03\nAbsolute structure: Flack (1983),\n340 Friedel pairs\nFlack parameter: /C00.05 (7)\nData collection: APEX2 (Bruker, 2008); cell reﬁnement: SAINT\n(Bruker, 2008); data reduction: SAINT ; program(s) used to solve\nstructure: SHELXS97 (Sheldrick, 2008); program(s) used to reﬁne\nstructure: SHELXL97 (Sheldrick, 2008); molecular graphics:\nSHELXTL (Sheldrick, 2008); software used to prepare material for\npublication: SHELXTL .\nThe authors acknowledge the Doctoral Foundation of\nHenan Polytechnic University (grant No. B2010–92, 648483).\nSupplementary data and ﬁgures for this paper are available from the\nIUCr electronic archives (Reference: FI2112).\nReferences\nAatiq, A., Haggouch, B., Bakri, R., Lakhdar, Y. & Saadoune, I. (2006). Powder\nDiffr. 21, 214–219.\nBruker (2008). APEX2 andSAINT . Bruker AXS Inc., Madison, Wisconsin,\nUSA.\nFlack, H. D. (1983). Acta Cryst. A39, 876–881.\nNorberg, S. T. (2002). Acta Cryst. B58, 743–749.\nOgorodnyk, I. V., Zatovsky, I. V ., Slobodyanik, N. S., Baumer, V. N. &\nShishkin, O. V . (2006). J. Solid State Chem. 179, 3461–3466.\nOrlova, A. I., Trubach, I. G., Kurazhkovskaya, V. S., Pertierra, P ., Salvado,\nM. A., Garcia-Granda, S., Khainakov, S. A. & Garcia, J. R. (2003). J. Solid\nState Chem. 173, 314–318.\nSheldrick, G. M. (1996). SADABS . University of Go ¨ttingen, Germany.\nSheldrick, G. M. (2008). Acta Cryst. A64, 112–122.\nZatovsky, I. V., Yatskin, M. M., Baumer, V . N., Slobodyanik, N. S. & Shishkin,\nO. V. (2007). Acta Cryst. E63, i199.\nZemann, A. & Zemann, J. (1957). Acta Cryst. 10, 409–413.\nZhao, D., Zhang, H., Huang, S. P ., Zhang, W. L., Yang, S. L. & Cheng, W. D.\n(2009). J. Alloys Compd ,477, 795–799.inorganic compounds\ni56 Li and Zhao doi:10.1107/S1600536811037263 Acta Cryst. (2011). E 67, i56Acta Crystallographica Section E\nStructure Reports\nOnline\nISSN 1600-5368\n'

# %%
txt = r.text

# %%
from bs4 import BeautifulSoup

# %%
os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = "1"

# %%
soup = BeautifulSoup(txt)
#soup.getText()

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
import torch

src_text = [
    """ PG&E stated it scheduled the blackouts in response to forecasts for high winds amid dry conditions. The aim is to reduce the risk of wildfires. Nearly 800 thousand customers were scheduled to be affected by the shutoffs which were expected to last through at least midday tomorrow."""
]

device = "mps"
tokenizer_news = PegasusTokenizer.from_pretrained("google/pegasus-cnn_dailymail", max_position_embeddings=2048)
tokenizer_xl = PegasusTokenizer.from_pretrained("google/pegasus-large", max_position_embeddings=2048)
model_news = PegasusForConditionalGeneration.from_pretrained("google/pegasus-cnn_dailymail", max_position_embeddings=2048).to(device)
model_xl = PegasusForConditionalGeneration.from_pretrained("google/pegasus-large", max_position_embeddings=2048).to(device)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [224], in <cell line: 14>()
#      12 model_xl = PegasusForConditionalGeneration.from_pretrained("google/pegasus-large", max_position_embeddings=2048).to(device)
#      13 batch = tokenizer_news(src_text, truncation=True, padding="longest", return_tensors="pt").to(device)
# ---> 14 translated = model_news.generate(**batch)
#      15 tgt_text = tokenizer_news.batch_decode(translated, skip_special_tokens=True)
#      16 print(tgt_text)
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/transformers/generation_utils.py:1360, in GenerationMixin.generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, **model_kwargs)
#    1356     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1357         input_ids, expand_size=num_beams, is_encoder_decoder=self.config.is_encoder_decoder, **model_kwargs
#    1358     )
#    1359     # 12. run beam search
# -> 1360     return self.beam_search(
#    1361         input_ids,
#    1362         beam_scorer,
#    1363         logits_processor=logits_processor,
#    1364         stopping_criteria=stopping_criteria,
#    1365         pad_token_id=pad_token_id,
#    1366         eos_token_id=eos_token_id,
#    1367         output_scores=output_scores,
#    1368         return_dict_in_generate=return_dict_in_generate,
#    1369         synced_gpus=synced_gpus,
#    1370         **model_kwargs,
#    1371     )
#    1373 elif is_beam_sample_gen_mode:
#    1374     # 10. prepare logits warper
#    1375     logits_warper = self._get_logits_warper(
#    1376         top_k=top_k,
#    1377         top_p=top_p,
#    (...)
#    1381         renormalize_logits=renormalize_logits,
#    1382     )
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/transformers/generation_utils.py:2260, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2255 next_token_scores, next_tokens = torch.topk(
#    2256     next_token_scores, 2 * num_beams, dim=1, largest=True, sorted=True
#    2257 )
#    2259 next_indices = torch_int_div(next_tokens, vocab_size)
# -> 2260 next_tokens = next_tokens % vocab_size
#    2262 # stateless
#    2263 beam_outputs = beam_scorer.process(
#    2264     input_ids,
#    2265     next_token_scores,
#    (...)
#    2270     beam_indices=beam_indices,
#    2271 )
#
# NotImplementedError: The operator 'aten::remainder.Tensor_out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.

# %%
model_news = model_news.to("mps")

# %%
from scidownl import scihub_download
import os

paper = "https://doi.org/"+data.doi.sample(n=1).iloc[0]
paper_type = "doi"
out = "./tmp.pdf"
scihub_download(paper, paper_type=paper_type, out=out)
pdfFileObj = open('tmp.pdf', 'rb')

pdfReader = PyPDF2.PdfReader(pdfFileObj)
   
text = pdfReader.pages[0].extract_text()

pdfFileObj.close()
os.remove("tmp.pdf")
prompt = " ".join(text.split(" ")[:400])
result_length = 200
inputs = tokenizer_news(prompt, return_tensors="pt")
print(tokenizer_news.decode(model_news.generate(inputs["input_ids"])[0]))
# Out:
# [INFO] | 2023/01/10 20:09:36 | Choose scihub url [0]: http://sci-hub.se
# [INFO] | 2023/01/10 20:09:37 | <- Request: scihub_url=http://sci-hub.se, source=DoiSource[type=doi, id=doi.org/10.1107/S1600536807020454]
# [INFO] | 2023/01/10 20:09:37 | -> Response: status_code=200, content_length=7130
# [INFO] | 2023/01/10 20:09:37 | * Extracted information: {'url': 'https://zero.sci-hub.se/524/8d9831ad01f0218b6c441b6b03b10ba3/ghorbani2007.pdf', 'title': '5-(4-Fluorophenyl)-1,3,7,9-tetramethylpyrido[2,3-d 6,5-d]dipyrimidine-2,4,6,8(1H,3H,7H,9H)-tetrone. Acta Crystallographica Section E Structure Reports Online, 63(6), o2790–o2790'}
#  59% [.............................................                               ] 401408 / 675061
# [INFO] | 2023/01/10 20:09:38 | ↓ Successfully download the url to: ./tmp.pdf
# 100% [............................................................................] 675061 / 675061
# Token indices sequence length is longer than the specified maximum sequence length for this model (1098 > 1024). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [228], in <cell line: 19>()
#      17 result_length = 200
#      18 inputs = tokenizer_news(prompt, return_tensors="pt")
# ---> 19 print(tokenizer_news.decode(model_news.generate(inputs["input_ids"])[0]))
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/transformers/generation_utils.py:1182, in GenerationMixin.generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, **model_kwargs)
#    1175     model_kwargs["attention_mask"] = self._prepare_attention_mask_for_generation(
#    1176         inputs_tensor, pad_token_id, eos_token_id
#    1177     )
#    1179 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1180     # if model is encoder decoder encoder_outputs are created
#    1181     # and added to `model_kwargs`
# -> 1182     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1183         inputs_tensor, model_kwargs, model_input_name
#    1184     )
#    1186 # 4. Prepare `input_ids` which will be used for auto-regressive generation
#    1187 if self.config.is_encoder_decoder:
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/transformers/generation_utils.py:525, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     523 encoder_kwargs["return_dict"] = True
#     524 encoder_kwargs[model_input_name] = inputs_tensor
# --> 525 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     527 return model_kwargs
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/transformers/models/pegasus/modeling_pegasus.py:761, in PegasusEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     758     raise ValueError("You have to specify either input_ids or inputs_embeds")
#     760 if inputs_embeds is None:
# --> 761     inputs_embeds = self.embed_tokens(input_ids) * self.embed_scale
#     763 embed_pos = self.embed_positions(input_shape)
#     765 hidden_states = inputs_embeds + embed_pos
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/sparse.py:160, in Embedding.forward(self, input)
#     159 def forward(self, input: Tensor) -> Tensor:
# --> 160     return F.embedding(
#     161         input, self.weight, self.padding_idx, self.max_norm,
#     162         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File /usr/local/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/functional.py:2206, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2200     # Note [embedding_renorm set_grad_enabled]
#    2201     # XXX: equivalent to
#    2202     # with torch.no_grad():
#    2203     #   torch.embedding_renorm_
#    2204     # remove once script supports set_grad_enabled
#    2205     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2206 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Placeholder storage has not been allocated on MPS device!
